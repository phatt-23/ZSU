# %% [markdown]
# # Fundamentals of Machine Learning - Exercise 1
# The aim of the exercise is to get an overview of the basic capabilities of the Pandas, Matplotlib and Seaborn libraries and be able to setup a Python Virtual Enviroment (`venv`)
#
# **Jupyter lab**
#
# * Add code
# * Add text
# * Execute command
# * Shortcuts (a, b, dd, Ctrl+Enter, Shift+Enter, x, c, v)
#
# **Alternatives**
#
# * Google Colab ([Colaboratory](https://colab.research.google.com/))
# * Python scripts in VS Code
#
# "![meme01](https://github.com/rasvob/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/fml_01_meme_01.png?raw=true)

# %% [markdown]
# # Data processing
#
# Data source: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# Important attributes description:
# * SalePrice: The property's sale price in dollars. This is the target variable that you're trying to predict.
# * MSSubClass: The building class
# * BldgType: Type of dwelling
# * HouseStyle: Style of dwelling
# * OverallQual: Overall material and finish quality
# * OverallCond: Overall condition rating
# * YearBuilt: Original construction date
# * Heating: Type of heating
# * CentralAir: Central air conditioning
# * GrLivArea: Above grade (ground) living area square feet
# * BedroomAbvGr: Number of bedrooms above basement level

# %% [markdown]
# ## Import used packages

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np # matrices and linear algebra
import matplotlib.pyplot as plt # plotting
import pandas as pd # dataframes
import seaborn as sns # another matplotlib interface - styled and easier to use

# %% [markdown]
# ## The first step is to load the data into the Pandas DataFrame - in our case it is a csv file
# * https://raw.githubusercontent.com/rasvob/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/master/datasets/zsu_cv1_data.csv

# %%
df_full = pd.read_csv("https://raw.githubusercontent.com/rasvob/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/master/datasets/zsu_cv1_data.csv")
df_full
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# ## We shloud take a look on the data after loading so we know that everything is OK

# %% [markdown]
# ### We will start with showing first/last N rows
# - There are several ways of doing that:
#     - name of the dataframe
#     - head()
#     - tail()

# %% [markdown]
# ### Show 5 first and last rows

# %%
df_full.head(5) + df_full.tail(5)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 1    NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 2    NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 3    NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 4    NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 1455 NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 1456 NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 1457 NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 1458 NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
# 1459 NaN         NaN      NaN          NaN      NaN    NaN   NaN      NaN
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0            NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 1            NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 2            NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 3            NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 4            NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 1455         NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 1456         NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 1457         NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 1458         NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
# 1459         NaN       NaN  ...      NaN    NaN   NaN         NaN     NaN
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       NaN    NaN       NaN            NaN        NaN
# 1       NaN    NaN       NaN            NaN        NaN
# 2       NaN    NaN       NaN            NaN        NaN
# 3       NaN    NaN       NaN            NaN        NaN
# 4       NaN    NaN       NaN            NaN        NaN
# 1455    NaN    NaN       NaN            NaN        NaN
# 1456    NaN    NaN       NaN            NaN        NaN
# 1457    NaN    NaN       NaN            NaN        NaN
# 1458    NaN    NaN       NaN            NaN        NaN
# 1459    NaN    NaN       NaN            NaN        NaN
#
# [10 rows x 81 columns]

# %% [markdown]
# ### Show first 5 rows

# %%
df_full.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Show last 20 rows

# %%
df_full.tail(20)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1440         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1441         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1442         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1443         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1444         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1445         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1446         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1447         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1448         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1449         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1450         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1451         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1452         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1453         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1440      9   2008        WD         Normal     191000
# 1441      5   2008        WD         Normal     149300
# 1442      4   2009        WD         Normal     310000
# 1443      5   2009        WD         Normal     121000
# 1444     11   2007        WD         Normal     179600
# 1445      5   2007        WD         Normal     129000
# 1446      4   2010        WD         Normal     157900
# 1447     12   2007        WD         Normal     240000
# 1448      5   2007        WD         Normal     112000
# 1449      8   2006        WD        Abnorml      92000
# 1450      9   2009        WD         Normal     136000
# 1451      5   2009       New        Partial     287090
# 1452      5   2006        WD         Normal     145000
# 1453      7   2006        WD        Abnorml      84500
# 1454     10   2009        WD         Normal     185000
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [20 rows x 81 columns]

# %% [markdown]
# ## If we want to know if there are any missing values, the isna() function may render useful

# %%
df_full
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# ## We can show summary of common statistical characteristic of the data using the describe() function

# %%
df_full.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ## 💡 Dataframe has several useful properties
#     - shape
#     - dtypes
#     - columns
#     - index

# %% [markdown]
# #### Row and column count

# %%
df_full.shape
# Out:
# (1460, 81)

# %% [markdown]
# #### Datatypes of columns

# %%
df_full.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# #### Column names

# %%
df_full.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# #### Row index values

# %%
# df_full.index
# for row in df_full:
#     print( row )

df_full.iloc[10:23]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# 12  13          20       RL          NaN    12968   Pave   NaN      IR2
# 13  14          20       RL         91.0    10652   Pave   NaN      IR1
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
# 16  17          20       RL          NaN    11241   Pave   NaN      IR1
# 17  18          90       RL         72.0    10791   Pave   NaN      Reg
# 18  19          20       RL         66.0    13695   Pave   NaN      Reg
# 19  20          20       RL         70.0     7560   Pave   NaN      Reg
# 20  21          60       RL        101.0    14215   Pave   NaN      IR1
# 21  22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22  23          20       RL         75.0     9742   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 10         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 11         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 12         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 13         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 14         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 15         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 16         Lvl    AllPub  ...        0    NaN    NaN        Shed     700
# 17         Lvl    AllPub  ...        0    NaN    NaN        Shed     500
# 18         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 19         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 20         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 21         Bnk    AllPub  ...        0    NaN  GdPrv         NaN       0
# 22         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# 10      2   2008        WD         Normal     129500
# 11      7   2006       New        Partial     345000
# 12      9   2008        WD         Normal     144000
# 13      8   2007       New        Partial     279500
# 14      5   2008        WD         Normal     157000
# 15      7   2007        WD         Normal     132000
# 16      3   2010        WD         Normal     149000
# 17     10   2006        WD         Normal      90000
# 18      6   2008        WD         Normal     159000
# 19      5   2009       COD        Abnorml     139000
# 20     11   2006       New        Partial     325300
# 21      6   2007        WD         Normal     139400
# 22      9   2008        WD         Normal     230000
#
# [13 rows x 81 columns]

# %% [markdown]
# ## We may want to work with just one column not the whole dataframe
# - We will select only the SalePrice columns and save it to another variable

# %%
prices = df_full["SalePrice"]
df_full
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# ## Columns are called Pandas Series - it shares a common API with Pandas DataFrame
# - 💡 Pandas has numpy-backed so we can use Series as standard numpy arrays without any issues using the .values property

# %%
array_np = df_full["SalePrice"].values
# array_np.sort()
array_np


# df_full["SalePrice"].sort_values()

# df_full["SalePrice"].values.sort()
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500], shape=(1460,))

# %% [markdown]
# ## Find maximum price using Numpy and Pandas

# %%
# df_full["SalePrice"].values.max()
np.max(df_full["SalePrice"].values)
# Out:
# np.int64(755000)

# %%
df_full["SalePrice"].max()
# Out:
# np.int64(755000)

# %% [markdown]
# ## Data filtering using Pandas DataFrame
# - There are several ways of filtering the data (similar logic to .Where() in C# or WHERE in SQL)
# - 💡 We usually work with two indexers - .loc[] and .iloc[]
#
# ### The .iloc[] indexer works with positional indexes - very close to the way of working with the raw arrays
# ### The .loc[] indexer works with column names and logical expressions

# %% [markdown]
# ### Select all rows and 3rd column of dataframe

# %%
df_full.iloc[:5,2]
# Out:
# 0    RL
# 1    RL
# 2    RL
# 3    RL
# 4    RL
# Name: MSZoning, dtype: object

# %% [markdown]
# ### Select all rows and LAST column of dataframe

# %%
df_full.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df_full.loc[[0, 4, 10], df_full.columns.values[2:10]]
# Out:
#    MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities
# 0        RL         65.0     8450   Pave   NaN      Reg         Lvl    AllPub
# 4        RL         84.0    14260   Pave   NaN      IR1         Lvl    AllPub
# 10       RL         70.0    11200   Pave   NaN      Reg         Lvl    AllPub

# %% [markdown]
# ### Select 4th to 10th row and all columns

# %%
df_full.loc[4:11, :]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 4          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5          Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7          Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 10         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 11         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# 4      12   2008        WD         Normal     250000
# 5      10   2009        WD         Normal     143000
# 6       8   2007        WD         Normal     307000
# 7      11   2009        WD         Normal     200000
# 8       4   2008        WD        Abnorml     129900
# 9       1   2008        WD         Normal     118000
# 10      2   2008        WD         Normal     129500
# 11      7   2006       New        Partial     345000
#
# [8 rows x 81 columns]

# %% [markdown]
# ### Select 2nd to 13th row and 3rd column

# %%
df_full.iloc[2:14, 2]
# Out:
# 2     RL
# 3     RL
# 4     RL
# 5     RL
# 6     RL
# 7     RL
# 8     RM
# 9     RL
# 10    RL
# 11    RL
# 12    RL
# 13    RL
# Name: MSZoning, dtype: object

# %% [markdown]
# ## Select only a subset of columns to a new dataframe
# * 'Id', 'SalePrice','MSSubClass','BldgType','HouseStyle','OverallQual','OverallCond','YearBuilt','Heating','CentralAir','GrLivArea','BedroomAbvGr'

# %%
df = df_full.loc[:, ['Id', 'SalePrice','MSSubClass','BldgType','HouseStyle','OverallQual','OverallCond','YearBuilt','Heating','CentralAir','GrLivArea','BedroomAbvGr']]
df.head()
# Out:
#    Id  SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 0   1     208500          60     1Fam     2Story            7            5
# 1   2     181500          20     1Fam     1Story            6            8
# 2   3     223500          60     1Fam     2Story            7            5
# 3   4     140000          70     1Fam     2Story            7            5
# 4   5     250000          60     1Fam     2Story            8            5
#
#    YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr
# 0       2003    GasA          Y       1710             3
# 1       1976    GasA          Y       1262             3
# 2       2001    GasA          Y       1786             3
# 3       1915    GasA          Y       1717             3
# 4       2000    GasA          Y       2198             4

# %% [markdown]
# ### Select only houses built in year 2000 or later
# * YearBuilt

# %%
df_full.loc[df.YearBuilt >= 2000, df.columns[:10]]
# Out:
#         Id  SalePrice  MSSubClass BldgType HouseStyle  OverallQual  \
# 0        1     208500          60     1Fam     2Story            7
# 2        3     223500          60     1Fam     2Story            7
# 4        5     250000          60     1Fam     2Story            8
# 6        7     307000          20     1Fam     1Story            8
# 11      12     345000          60     1Fam     2Story            9
# ...    ...        ...         ...      ...        ...          ...
# 1444  1445     179600          20     1Fam     1Story            7
# 1451  1452     287090          20     1Fam     1Story            8
# 1452  1453     145000         180   TwnhsE       SLvl            5
# 1453  1454      84500          20     1Fam     1Story            5
# 1454  1455     185000          20     1Fam     1Story            7
#
#       OverallCond  YearBuilt Heating CentralAir
# 0               5       2003    GasA          Y
# 2               5       2001    GasA          Y
# 4               5       2000    GasA          Y
# 6               5       2004    GasA          Y
# 11              5       2005    GasA          Y
# ...           ...        ...     ...        ...
# 1444            5       2004    GasA          Y
# 1451            5       2008    GasA          Y
# 1452            5       2005    GasA          Y
# 1453            5       2006    GasA          Y
# 1454            5       2004    GasA          Y
#
# [388 rows x 10 columns]

# %% [markdown]
# ### Select only houses that don't use GasA for heating (!= or ~ operators)
# * Heating

# %%
df_full.loc[df.Heating != "GasA"] 
df_full.loc[~(df.Heating == "GasA")]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 69      70          50       RL         81.0    15593   Pave   NaN      Reg
# 93      94         190  C (all)         60.0     7200   Pave   NaN      Reg
# 108    109          50       RM         85.0     8500   Pave   NaN      Reg
# 155    156          50       RL         60.0     9600   Pave   NaN      Reg
# 275    276          50       RL         55.0     7264   Pave   NaN      Reg
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 342    343          90       RL          NaN     8544   Pave   NaN      Reg
# 417    418          70       RL         86.0    22420   Pave   NaN      IR1
# 514    515          45       RL         55.0    10594   Pave   NaN      Reg
# 636    637          30       RM         51.0     6120   Pave   NaN      Reg
# 676    677          70       RM         60.0     9600   Pave  Grvl      Reg
# 713    714         190       RL         60.0     9873   Pave   NaN      Reg
# 735    736          75       RM         60.0    10800   Pave   NaN      Reg
# 747    748          70       RM         65.0    11700   Pave  Pave      IR1
# 749    750          50       RL         50.0     8405   Pave   NaN      Reg
# 814    815          50       RL         45.0     8248   Pave  Grvl      Reg
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
# 985    986         190       RL         68.0    10880   Pave   NaN      Reg
# 1000  1001          20       RL         74.0    10206   Pave   NaN      Reg
# 1013  1014          30       RM         60.0     7200   Pave   NaN      Reg
# 1090  1091          90       RL         60.0     8544   Pave   NaN      Reg
# 1132  1133          70       RM         90.0     9900   Pave   NaN      Reg
# 1144  1145         190       RL         60.0    12180   Pave   NaN      Reg
# 1248  1249          75       RM         60.0     9600   Pave  Grvl      Reg
# 1269  1270          50       RL         78.0    11344   Pave   NaN      Reg
# 1321  1322          20       RL          NaN     6627   Pave   NaN      IR1
# 1328  1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 1337  1338          30       RM        153.0     4118   Pave  Grvl      IR1
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1387  1388          50       RM         60.0     8520   Pave  Grvl      Reg
# 1412  1413          90       RL         60.0     7200   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 69           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 93           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 108          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 155          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 275          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 313          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 342          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 417          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 514          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 636          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 676          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 713          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 735          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 747          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 749          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 814          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 968          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 985          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1000         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1013         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1090         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1132         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1144         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1248         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1269         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1321         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1328         Lvl    AllPub  ...        0    NaN  MnPrv        Shed    1150
# 1337         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1349         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1387         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1412         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1443         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 69        7   2006        WD         Normal     225000
# 93       11   2007        WD         Normal     133900
# 108       8   2007        WD         Normal     115000
# 155       4   2008        WD         Normal      79000
# 275      10   2009        WD         Normal     205000
# 313       6   2009        WD         Normal     375000
# 342       5   2006        WD         Normal      87500
# 417      11   2007        WD         Normal     239000
# 514       6   2007        WD         Normal      96500
# 636       1   2009     ConLw         Normal      60000
# 676       5   2006        WD         Normal      87000
# 713       5   2006        WD         Normal     129000
# 735      10   2006        WD         Normal     163000
# 747       5   2009        WD         Normal     265979
# 749       4   2009        WD         Normal      98000
# 814       7   2006        WD         Normal     116000
# 968       5   2009        WD        Abnorml      37900
# 985       8   2008     ConLD         Normal     125000
# 1000      7   2009        WD         Normal      82000
# 1013      6   2009        WD         Normal      85000
# 1090      6   2009        WD         Normal      92900
# 1132      5   2007        WD         Normal     117500
# 1144      7   2010        WD         Normal      80000
# 1248      4   2008        WD         Normal     129500
# 1269      7   2007        WD         Normal     144000
# 1321      7   2008        WD         Normal      72500
# 1328      6   2008        WD         Normal     256000
# 1337      3   2006        WD         Normal      52500
# 1349     12   2008        WD         Normal     122000
# 1387      8   2007       CWD         Family     136000
# 1412      6   2009        WD         Normal      90000
# 1443      5   2009        WD         Normal     121000
#
# [32 rows x 81 columns]

# %% [markdown]
# ### Select houses cheaper than 180k USD and with at least 2 bedrooms
# * SalePrice, BedroomAbvGr

# %% [markdown]
# ### Select houses with 2 stories or air conditioning
# * HouseStyle, CentralAir

# %%
df_full["CentralAir"]
df_full["HouseStyle"]
df_full.loc[(df.HouseStyle == "2Story") | (df.CentralAir == "Y")].head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # We can add new columns to the DataFrame as well
#
# ![meme01](https://github.com/rasvob/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/fml_01_meme_02.png?raw=true)

# %% [markdown]
# ### Add a new column named Age for each house (current year - year built)
# * YearBuilt

# %%
"YearBuilt" in df.columns
# Out:
# True

# %%
df.loc[:, "Age"] = 2025 - df.YearBuilt

# %%
df["Age"]
# Out:
# 0        22
# 1        49
# 2        24
# 3       110
# 4        25
#        ...
# 1455     26
# 1456     47
# 1457     84
# 1458     75
# 1459     60
# Name: Age, Length: 1460, dtype: int64

# %% [markdown]
# ### Add a new column IsLuxury with True value for houses with more than 3 bedrooms and price above 214k USD (.loc)
# - How many luxury houses are in the dataset?
# - SalePrice, BedroomAbvGr

# %%
df.columns
# "BedroomAbvGr" in df.columns
# df.loc[:, 'IsLuxury']
# df.IsLuxury = False
# df.loc[:, 'IsLuxury'] = False
# df.loc[:]
# df.loc[(df.BedroomAbvGr >= 3) & (df.SalePrice > 214_000), 'IsLuxury'] = True
df.loc[:]
# Out:
#         Id  SalePrice  MSSubClass BldgType HouseStyle  OverallQual  \
# 0        1     208500          60     1Fam     2Story            7
# 1        2     181500          20     1Fam     1Story            6
# 2        3     223500          60     1Fam     2Story            7
# 3        4     140000          70     1Fam     2Story            7
# 4        5     250000          60     1Fam     2Story            8
# ...    ...        ...         ...      ...        ...          ...
# 1455  1456     175000          60     1Fam     2Story            6
# 1456  1457     210000          20     1Fam     1Story            6
# 1457  1458     266500          70     1Fam     2Story            7
# 1458  1459     142125          20     1Fam     1Story            5
# 1459  1460     147500          20     1Fam     1Story            5
#
#       OverallCond  YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr  Age
# 0               5       2003    GasA          Y       1710             3   22
# 1               8       1976    GasA          Y       1262             3   49
# 2               5       2001    GasA          Y       1786             3   24
# 3               5       1915    GasA          Y       1717             3  110
# 4               5       2000    GasA          Y       2198             4   25
# ...           ...        ...     ...        ...        ...           ...  ...
# 1455            5       1999    GasA          Y       1647             3   26
# 1456            6       1978    GasA          Y       2073             3   47
# 1457            9       1941    GasA          Y       2340             4   84
# 1458            6       1950    GasA          Y       1078             2   75
# 1459            6       1965    GasA          Y       1256             3   60
#
# [1460 rows x 13 columns]

# %% [markdown]
# ## Pandas enables us to use aggregation functions for the data using the .groupby() function

# %% [markdown]
# ### Compute counts for all the heating methods (groupby / value_counts)
# * Heating

# %%
df.groupby("Heating").Heating.count()
df.groupby("Heating").Heating.size()
df.groupby(df.Heating.name).Heating.size()
df.groupby(df.BedroomAbvGr).BedroomAbvGr.count()
df.groupby(df.BedroomAbvGr).count().iloc[:, 0]
# Out:
# BedroomAbvGr
# 0      6
# 1     50
# 2    358
# 3    804
# 4    213
# 5     21
# 6      7
# 8      1
# Name: Id, dtype: int64

# %%
df.Heating.value_counts()
df.BedroomAbvGr.value_counts()
# Out:
# BedroomAbvGr
# 3    804
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: count, dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Scatter plot
# - Visualize relationship between SalePrice and GrLivArea.
# - Use scatter plot from **Matplotlib**.

# %%
# plt.scatter(x=df.SalePrice, y=df.Age)
# plt.boxplot(x=df.SalePrice)
# plt.show()

plt.scatter(x=df.YearBuilt, y=df.GrLivArea)
plt.show()

# %%
df.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Modify figure size and add title

# %%
# f = plt.figure(figsize=(10, 10))
# plt.title("Figure 'f'");
# plt.boxplot(x=df.SalePrice)

fig = plt.figure(figsize=(20, 20))

plt.scatter(x=df['GrLivArea'], y=df['SalePrice'], color=df['CentralAir'].map({"Y": "blue", "N": "red"}))
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# ### Add axis labels

# %%
fig = plt.figure(figsize=(20, 10))
plt.scatter(x=df.GrLivArea, y=df.SalePrice)
plt.title("Sale Prices by Living area")
plt.ylabel(df.SalePrice.name)
plt.xlabel(df.GrLivArea.name)
plt.show()

# %% [markdown]
# ### Add colors for data points based on CentralAir value.

# %%
fig = plt.figure(figsize=(20, 10))
plt.scatter(x=df.GrLivArea, y=df.SalePrice, color=df.CentralAir.map({ "Y": "blue", "N": "red" }))
plt.title("Sale Prices by Living area")
plt.ylabel(df.SalePrice.name)
plt.xlabel(df.GrLivArea.name)
plt.show()

# %% [markdown]
# ## Try to use scatterplot from **Seaborn** library for scatter plot visualization.

# %% [markdown]
# #### Use dataframe as source and column names for axes data

# %%
sns.scatterplot(x=df.GrLivArea, y=df.SalePrice, color=df.CentralAir.map({ "Y": "blue", "N": "red" }))
sns.scatterplot(
    x=df.GrLivArea,
    y=df.SalePrice,
    hue=df.Age
    
)
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# ### Resize plot and add color for markers based on CentralAir column

# %%
plt.figure(figsize=(20, 20))
sns.scatterplot(
    data=df,
    x='GrLivArea',
    y=df.SalePrice,
    hue=df.CentralAir,
    
)
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# ## Line plot
# - Calculate and vizualize average house price in relationship to YearBuild.

# %%
data = df.groupby(df.YearBuilt).SalePrice.mean()
sns.lineplot(x=data.index, y=data.values, marker='X')
# data.index
# data.values
# Out:
# <Axes: xlabel='YearBuilt'>

# %% [markdown]
# ## Bar plot
# - Calculate and vizualize how many of houses have CentralAir
# - Use Barplot for visualization

# %%
data = df.CentralAir.value_counts()
sns.barplot(x=data.index, y=data.values)
# Out:
# <Axes: xlabel='CentralAir'>

# %% [markdown]
# ### Vizualize number of building type and if they contains air conditioning using Seaborn

# %%
data = df.groupby(by=["BldgType", "CentralAir"]).Id.count().reset_index(name="Count")
data
# Out:
#   BldgType CentralAir  Count
# 0     1Fam          N     68
# 1     1Fam          Y   1152
# 2   2fmCon          N     15
# 3   2fmCon          Y     16
# 4   Duplex          N     12
# 5   Duplex          Y     40
# 6    Twnhs          Y     43
# 7   TwnhsE          Y    114

# %%
sns.barplot(x=data.BldgType, y=data.Count, hue=data.CentralAir)
# Out:
# <Axes: xlabel='BldgType', ylabel='Count'>

# %% [markdown]
# ## ✅ Vizualization (1 pt)
# * Add to dataframe new attribute determining if the house was build before or after year 2000.
#
# * **Create bar chart for number of houses depending on type of dwelling (attribute BldgType, use as a category axis) and added binary attribute about house age (use as a bar color).**

# %%
df['AfterScndMillenium'] = df.YearBuilt > 2000
# Out:
#   BldgType  AfterScndMillenium  Count
# 0     1Fam               False    930
# 1     1Fam                True    290
# 2   2fmCon               False     31
# 3   Duplex               False     52
# 4    Twnhs               False     32
# 5    Twnhs                True     11
# 6   TwnhsE               False     51
# 7   TwnhsE                True     63

# %%
data = df.groupby(by=[df.BldgType, df.AfterScndMillenium]).Id.count().reset_index(name="Count")
data
# Out:
#   BldgType  AfterScndMillenium  Count
# 0     1Fam               False    930
# 1     1Fam                True    290
# 2   2fmCon               False     31
# 3   Duplex               False     52
# 4    Twnhs               False     32
# 5    Twnhs                True     11
# 6   TwnhsE               False     51
# 7   TwnhsE                True     63

# %%
sns.barplot(x=data.BldgType, y=data.Count, hue=data.AfterScndMillenium)
# Out:
# <Axes: xlabel='BldgType', ylabel='Count'>

# %% [markdown]
# ## ✅ Pandas (1 pt)
# * Add a new column *Undervalued* which is set to True in case that the house is priced bellow 163k USD and has both OverallQual and OverallCond higher than 5.
#
# * **How many undervalued houses are in the dataset?**

# %%
df['Undervalued'] = False

# %%
df.loc[(df.SalePrice < 163_000) & (df.OverallQual > 5) & (df.OverallCond > 5), 'Undervalued'] = True;

# %%
df.Undervalued.value_counts()
# Out:
# Undervalued
# False    1340
# True      120
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x=df.GrLivArea, y=df.SalePrice, hue=df.Undervalued)
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>
